# %% [markdown]
# # Lab Activity Week 6
#
# **Homework** Anythin you do not complete in lab is your homework. Please provide a link to your github repository as your homework submission.

# %% [markdown]
# ### Step 1: Aquiring data
#
# - Collect data from your weather and air quality sensors together (in the same script) for 5 minutes, taking a reading every second.
# - Make the name of the file saving the data something that is unique each time data is recorded.
#    - **HINT:** You can include the time as part of the file name, for example.
# - Upload your new data to your git repository on GitHub and update the version of your respository on your laptop

# %% [markdown]
# ### Step 2: Acquiring outdoor data
# - Restart your raspberry pi system, powering it with the supplied batteries, rather than the power adaptor.
# - Add a time delay to the start of your data acquisition script (as an optional user input)
# - Start your data aquisition to again collect data for 5 minutes, taking readings every second, but this time with an initial ~2 minute delay (so it should run for ~7 minutes total).
# - Take the whole system outdoors and wait there for the 5 minutes of data acquisition to complete.
# - At your stations, again push your new data to your git repository on GitHub

# %% [markdown]
# ### Step 3: Plotting indoor data
# - Create a new Jupyter notebook and load (using pandas, for example) the data you now have from your device.
# - Plot each type of data as a frequency distribution (histogram) with appropriate binning - meaning the distribution shows a good level of detail but does not have binning artifacts
# - Using the mean and standard deviation of each set of data, does any of the data you have recorded look like it is well described by a normal distribution?
#   - Using the mean and standard deviation, try plotting a Gaussian function along with each of your frequency distributions and see how well they match.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('datal4.csv')


num_bins = 20

for column in data.columns:
    mu, std = data[column].mean(), data[column].std()
    
    plt.hist(data[column], bins=num_bins, density=True)
    
    x = np.linspace(data[column].min(), data[column].max(), 100)
    
    y = np.exp(-(x - mu)**2 / (2 * std**2)) / (np.sqrt(2 * np.pi) * std)
    plt.plot(x, y, 'r--', linewidth=2)
    
    plt.title(f'Frequency Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    plt.show()
# Out:
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/2208251157.py:17: RuntimeWarning: invalid value encountered in true_divide
#   y = np.exp(-(x - mu)**2 / (2 * std**2)) / (np.sqrt(2 * np.pi) * std)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1621         try:
# -> 1622             x = float(x)
#    1623         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '2023-02-15 16:54:43.3289462023-02-15 16:54:44.5223002023-02-15 16:54:45.7156092023-02-15 16:54:46.9088862023-02-15 16:54:48.1009382023-02-15 16:54:49.3003812023-02-15 16:54:50.4950072023-02-15 16:54:51.6964482023-02-15 16:54:52.8974122023-02-15 16:54:54.0904672023-02-15 16:54:55.2909652023-02-15 16:54:56.4906662023-02-15 16:54:57.6834012023-02-15 16:54:58.8775662023-02-15 16:55:00.0773142023-02-15 16:55:01.2717972023-02-15 16:55:02.4663802023-02-15 16:55:03.6677662023-02-15 16:55:04.8604952023-02-15 16:55:06.0600552023-02-15 16:55:07.2529462023-02-15 16:55:08.4461352023-02-15 16:55:09.6458812023-02-15 16:55:10.8389632023-02-15 16:55:12.0319402023-02-15 16:55:13.2321182023-02-15 16:55:14.4281742023-02-15 16:55:15.6255762023-02-15 16:55:16.8200552023-02-15 16:55:18.0143102023-02-15 16:55:19.2115052023-02-15 16:55:20.4047852023-02-15 16:55:21.6030812023-02-15 16:55:22.7955342023-02-15 
# %% [markdown]
# ### Step 4: Comparing Indoor vs Outdoor data
# - Produce the same plots as in Step 2 for your new outdoor data
# - Now produce plots that compare indoors vs outdoors for each of your data types - don't forget labels
# - Comment on your results
# - Compare the mean and standard deviation values for each set of indoor data versus outdoor data, are they in agreement?
#   - NOTE: The variance in your data is not the uncertainty on the mean (central limit theorem)
#   - what is your mean uncertainty?
#   - How many inside mean standard deviations (1 sigma uncertainty) are your inside and outside measurements separated by?
# - If your distributions were not well described by a Gaussian, do you think you took enough data for the central limit theorem to apply?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = pd.read_csv('datal4.csv')

data2 = pd.read_csv('data2023-02-22_16-07-25.csv')


num_bins = 20

for column in data1.columns:
    mu1, std1 = data1[column].mean(), data1[column].std()
    mu2, std2 = data2[column].mean(), data2[column].std()
    
    plt.hist(data1[column], bins=num_bins, density=True, label='Inside Data')
    plt.hist(data2[column], bins=num_bins, density=True, label='Outside Data')
    
    x = np.linspace(min(data1[column].min(), data2[column].min()), max(data1[column].max(), data2[column].max()), 100)
    
    y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
    y2 = (1/(np.sqrt(2*np.pi)*std2))*np.exp(-((x-mu2)**2)/(2*std2**2))
    
    plt.plot(x, y1, 'r--', linewidth=2, label='Inside Gaussian')
    plt.plot(x, y2, 'b--', linewidth=2, label='Outside Gaussian')
    
    plt.title(f'Frequency Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    
    # display the plot
    plt.show()
# Out:
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/3085557438.py:21: RuntimeWarning: divide by zero encountered in double_scalars
#   y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/3085557438.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/3085557438.py:21: RuntimeWarning: invalid value encountered in true_divide
#   y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/3085557438.py:21: RuntimeWarning: invalid value encountered in multiply
#   y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1621         try:
# -> 1622             x = float(x)
#    1623         except (TypeError, ValueError):
#
023-02-15 16:57:11.7147172023-02-15 16:57:12.9081992023-02-15 16:57:14.1014232023-02-15 16:57:15.3005732023-02-15 16:57:16.5003692023-02-15 16:57:17.6941152023-02-15 16:57:18.8873462023-02-15 16:57:20.0868552023-02-15 16:57:21.2866202023-02-15 16:57:22.4862262023-02-15 16:57:23.6791642023-02-15 16:57:24.8788192023-02-15 16:57:26.0785372023-02-15 16:57:27.2714962023-02-15 16:57:28.4645722023-02-15 16:57:29.6637842023-02-15 16:57:30.8568992023-02-15 16:57:32.0564112023-02-15 16:57:33.2493852023-02-15 16:57:34.4494052023-02-15 16:57:35.6491012023-02-15 16:57:36.8484332023-02-15 16:57:38.0432342023-02-15 16:57:39.2469542023-02-15 16:57:40.4463782023-02-15 16:57:41.6392182023-02-15 16:57:42.8323402023-02-15 16:57:44.0318402023-02-15 16:57:45 ...

# %% [markdown]
# ### Step 5: Comparing sensors
# - Get data from another group in your lab and compare your inside data with their inside data, including all of elements from Step 4. Do the same comparing your outside data with their outside data.
# - How do the sensors compare? What do you think this indicates about the accuracy and precision of your sensors?

# %% [markdown]
# # UNUSABLE DATA
#
# Unforately in this step, we are unable to use the data we were received by the parter group since our column structure and titles are different. It seems like that the way we took down data in different time formats will not be possible to compare without having the same column and data frame structure.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = pd.read_csv('datal4.csv')

data2 = pd.read_csv('file_second.csv')

num_bins = 20

for column in data1.columns:
    mu1, std1 = data1[column].mean(), data1[column].std()
    mu2, std2 = data2[column].mean(), data2[column].std()
    
    plt.hist(data1[column], bins=num_bins, density=True, label='OUR Inside Data')
    plt.hist(data2[column], bins=num_bins, density=True, label='THEIR Inside Data')
    
    x = np.linspace(min(data1[column].min(), data2[column].min()), max(data1[column].max(), data2[column].max()), 100)
    
    y1 = (1/(np.sqrt(2*np.pi)*std1))*np.exp(-((x-mu1)**2)/(2*std1**2))
    y2 = (1/(np.sqrt(2*np.pi)*std2))*np.exp(-((x-mu2)**2)/(2*std2**2))
    
    plt.plot(x, y1, 'r--', linewidth=2, label='OUR Inside Gaussian')
    plt.plot(x, y2, 'b--', linewidth=2, label='THEIR Inside Gaussian')
    
    plt.title(f'Frequency Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    
    # display the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PM1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/r0/377cn9d12fx8n9qsb37cxrgm0000gn/T/ipykernel_28007/1464135509.py in <module>
#      11 for column in data1.columns:
#      12     mu1, std1 = data1[column].mean(), data1[column].std()
# ---> 13     mu2, std2 = data2[column].mean(), data2[column].std()
#      14
#      15     plt.hist(data1[column], bins=num_bins, density=True, label='OUR Inside Data')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PM1'

# %% [markdown]
# ### Extra: Correlations in data
# - Plot temperature vs humidity
#   - NOTE: These were taken by the same sensor at the same time, so each measurement matches up in time, meaning plotting one versus the other works.
#   - What is the hidden variable that is important when making plots like this?
# - What does this plot show? Are temperature and humidity correlated? How might you quantify this?
#
# - Plot temperature vs another property measured by that sensor, are they correlated? Is the correlation qualitatively similar to what you see from temperature vs humidity?
#   - try this for all data types (temp. vs pressure, temp. vs voc, etc.)
#
# - Plot temperature vs PM2.5 concentration and discuss as with the previous comparisons.
